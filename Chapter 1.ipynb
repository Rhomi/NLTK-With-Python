# %%
import nltk

# %% [markdown]
# ### Install the data required for the book

# %%
# choose the book collection and click on download. Once its donwloaded its marked/highlighted in green.
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %% [raw]
# Once the data is downloaded to your machine, we can load some of it here.
# The book module contains all the data you will need as you read this chapter.

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [raw]
# Any time we want to find out about these texts, we just have to enter their names as follows:

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
text2
# Out:
# <Text: Sense and Sensibility by Jane Austen 1811>

# %% [markdown]
# ## Lets get into some  basic analysis

# %% [markdown]
# ### 1.1 Searching Text

# %% [markdown]
# ### There are many ways to examine the context of a text apart from simply reading it.
# A "concordance" view shows us every occurrence of a given word, together with some context. Here we look up the word love in Moby Dick
#
# #### Note : The first time you use a concordance on a particular text, it takes a few extra seconds to build an index so that subsequent searches are fast.

# %%
text1.concordance("love")
# Out:
# Displaying 24 of 24 matches:
#  to bespeak a monument for her first love , who had been killed by a whale in
# erlasting itch for things remote . I love to sail forbidden seas , and land on
# astic our stiff prejudices grow when love once comes to bend them . For now I
# ng . Now , it was plainly a labor of love for Captain Sleet to describe , as h
# he whole , I greatly admire and even love the brave , the honest , and learned
# to - night with hearts as light , To love , as gay and fleeting As bubbles tha
# he fleece of celestial innocence and love ; and hence , by bringing together t
# s this visible world seems formed in love , the invisible spheres were formed
# tism in them , still , while for the love of it they give chase to Moby Dick ,
# own hearty good - will and brotherly love about it at all . As touching Slave
# stubborn , as malicious . He did not love Steelkilt , and Steelkilt knew it .
#  of sea - usages and the instinctive love of neatness in seamen ; some of whom
# ...

# %% [markdown]
# ### Now, Search the book of Genesis to find out how many times the word "Almighty" was used

# %%
text3.concordance("Almighty")
# Out:
# Displaying 6 of 6 matches:
# ram , and said unto him , I am the Almighty God ; walk before me , and be thou
# n thy mother ' s brother . And God Almighty bless thee , and make thee fruitfu
# . And God said unto him , I am God Almighty : be fruitful and multiply ; a nat
#  , go again unto the man : And God Almighty give you mercy before the man , th
# . And Jacob said unto Joseph , God Almighty appeared unto me at Luz in the lan
# , who shall help thee ; and by the Almighty , who shall bless thee with blessi

# %%
text3.concordance("almighty")
# Out:
# Displaying 6 of 6 matches:
# ram , and said unto him , I am the Almighty God ; walk before me , and be thou
# n thy mother ' s brother . And God Almighty bless thee , and make thee fruitfu
# . And God said unto him , I am God Almighty : be fruitful and multiply ; a nat
#  , go again unto the man : And God Almighty give you mercy before the man , th
# . And Jacob said unto Joseph , God Almighty appeared unto me at Luz in the lan
# , who shall help thee ; and by the Almighty , who shall bless thee with blessi

# %% [raw]
# 1. Note that concordance is not case sensitive and returns the same results above.
# 2. One of the biggest advantages here is that a concordance permits us to see words in context.

# %% [markdown]
# ### What other words appear in a similar range of contexts? We can find out by appending the term similar to the name of the text in question, then inserting the relevant word in parentheses:

# %%
text3.similar("Almighty")
# Out:
# shall lord garden that will horite mighty everlasting beginning man

# %%
text1.similar("love")
# Out:
# man sea it ship captain me boats them bone matter sharks nature life
# air hand way head water blubber place

# %% [markdown]
# ### Now let's see in what context Jane Austen has used the word love in her novel "Sense and Sensibility"

# %%
text2.similar("love")
# Out:
# affection town heart see mother sister time me word elinor life it
# marianne dear family him bed do regard her

# %% [markdown]
# #### Notice the difference in contexts?
# Herman has used love in a different setting and contexts as compared to Jane.
# Herman has associated love with places, activities, lifestyle choices, generally giving a very outdoorsy vibe.
# Jane has associated love with people, places, family and gives a more bonding and nostalgic vibe.

# %% [markdown]
# ### The term "common_contexts" allows us to examine just the contexts that are shared by two or more words, such as monstrous and very. We have to enclose these words by square brackets as well as parentheses, and separate them with a comma:

# %%
text2.common_contexts(["love","time"])
# Out:
# and_and in_to to_and her_and and_to my_and my_that

# %% [markdown]
# #### It is one thing to automatically detect that a particular word occurs in a text, and to display some words that appear in the same context. However, we can also determine the location of a word in the text: how frequently they appear from the beginning.
#
# #### This positional information can be displayed using a dispersion plot.
#
# 1. Each stripe represents an instance of a word, and
# 2. Each row represents the entire text.

# %%
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America"])

# %% [markdown]
# ### 1.2 Counting Vocabulary

# %% [markdown]
# #### The most obvious fact about texts that emerges from the preceding examples is that they differ in the vocabulary they use.

# %% [markdown]
#    #### Let's begin by finding out the length of a text from start to finish, in terms of the words and punctuation symbols that appear. We use the term len to get the length of something, which we'll apply here to the book of Genesis:

# %%
len(text3)
# Out:
# 44764

# %% [markdown]
# #### So Genesis has 44,764 words and punctuation symbols, or "tokens."
#
# #### A token is the technical name for a sequence of characters — such as hello, his, or :) that we want to treat as a group (or a single sequence).
#
# #### When we count the number of tokens in a text, say, the phrase "to be or not to be", we are counting occurrences of these sequences (tokens).
# Thus, in our example phrase there are two occurrences of 'to', two of 'be', and one each of 'or' and 'not'. But there are only four distinct vocabulary items in this phrase.
#
# #### How many distinct words does the book of Genesis contain? To work this out in Python, we have to pose the question slightly differently.
#
# #### The vocabulary of a text is just the set of tokens that it uses. In a set, all duplicates are collapsed together.
# #### In Python we can obtain the vocabulary items of text3 with the command: set(text3). When you do this, many screens of words will fly past. Now try the following:

# %%
set(text3)
# Out:
# {u'alo',
#  u'Leah',
#  u'Night',
#  u'Matred',
#  u'four',
#  u'hath',
#  u'protest',
#  u'sleep',
#  u'captain',
#  u'integrity',
#  u'yonder',
#  u'Ehi',
#  u'sevens',
#  u'whose',
#  u'feeding',
#  u'Peniel',
#  u'intreat',
#  u'sinew',
#  u'whatsoever',
#  u'under',
#  u'lord',
#  u'spee',
#  u'worth',
#  u'Mehujael',
#  u'merchant',
#  u'tarry',
#  u'void',
#  u'rise',
#  u'every',
#  u'nourished',
#  u'confederate',
#  u'wagons',
#  u'Gether',
#  u'Lest',
#  u'clothed',
#  u'conceive',
#  u'red',
#  u'guiding',
#  u'Go',
#  u'clothes',
#  u'favoured',
#  u'parted',
#  u'Rachel',
#  u'force',
#  u'nigh',
#  u'welfare',
#  u'direct',
#  u'second',
#  u'street',
#  u'creepeth',
#  u'air',
#  u'Hadoram',
#  u'even',
#  u'Canaan',
#  u'hide',
#  u'deferred',
#  u'hate',
#  u'generatio',
#  u'fatness',
#  u'lights',
#  u'above',
#  u'Put',
#  u'ever',
#  u'told',
#  u'Havilah',
#  u'herb',
#  u'men',
#  u'kindred',
#  u'Mizpah',
#  u'drew',
#  u'herd',
#  u'met',
#  u'Mahanaim',
# ...

# %%
# By wrapping sorted() around the Python expression set(text3), we obtain a sorted list of vocabulary
# items, beginning with various punctuation symbols and continuing with words starting with A. 
# All capitalized words precede lowercase words.

sorted(set(text3))
# Out:
# [u'!',
#  u"'",
#  u'(',
#  u')',
#  u',',
#  u',)',
#  u'.',
#  u'.)',
#  u':',
#  u';',
#  u';)',
#  u'?',
#  u'?)',
#  u'A',
#  u'Abel',
#  u'Abelmizraim',
#  u'Abidah',
#  u'Abide',
#  u'Abimael',
#  u'Abimelech',
#  u'Abr',
#  u'Abrah',
#  u'Abraham',
#  u'Abram',
#  u'Accad',
#  u'Achbor',
#  u'Adah',
#  u'Adam',
#  u'Adbeel',
#  u'Admah',
#  u'Adullamite',
#  u'After',
#  u'Aholibamah',
#  u'Ahuzzath',
#  u'Ajah',
#  u'Akan',
#  u'All',
#  u'Allonbachuth',
#  u'Almighty',
#  u'Almodad',
#  u'Also',
#  u'Alvah',
#  u'Alvan',
#  u'Am',
#  u'Amal',
#  u'Amalek',
#  u'Amalekites',
#  u'Ammon',
#  u'Amorite',
#  u'Amorites',
#  u'Amraphel',
#  u'An',
#  u'Anah',
#  u'Anamim',
#  u'And',
#  u'Aner',
#  u'Angel',
#  u'Appoint',
#  u'Aram',
#  u'Aran',
#  u'Ararat',
#  u'Arbah',
#  u'Ard',
#  u'Are',
#  u'Areli',
#  u'Arioch',
#  u'Arise',
#  u'Arkite',
#  u'Arodi',
#  u'Arphaxad',
#  u'Art',
#  u'Arvadite',
#  u'As',
#  u'Asenath',
#  u'Ashbel',
#  u'Asher',
#  u'Ashkenaz',
# ...

# %%
# We discover the size of the vocabulary indirectly, by asking for the number of items in the set,
# and again we can use len to obtain this number
len(set(text3))
# Out:
# 2789

# %% [markdown]
# ### Although the book of Genesis has 44,764 tokens, it only has 2,789 distinct words, or "word types."
# A word type is the form or spelling of the word independently of its specific occurrences in a text — that is, the word considered as a unique item of vocabulary. Our count of 2,789 items will include punctuation symbols, so we will generally call these unique items types instead of word types.

# %% [markdown]
# Now, let's calculate a measure of the lexical richness of the text. We are going to compare the number of distinct words against the total number of words in the text.

# %%
import sys
sys.version
sys.version_info
# Out:
# sys.version_info(major=2, minor=7, micro=12, releaselevel='final', serial=0)

# %% [markdown]
# #### I just found out that I am using Python 2. Hence, I will have to use future_import to perform the next operation

# %%
from __future__ import division
len(set(text3)) / len(text3)
# Out:
# 0.06230453042623537

# %% [raw]
# This means that each word is used 16 times on average. Only 6% of the total number of words are unique

# %% [markdown]
# ### Next, let's focus on particular words. We can count how often a word occurs in a text, and compute what percentage of the text is taken up by a specific word:

# %%
text3.count("Almighty")
# Out:
# 6

# %%
from __future__ import division
(text3.count("Almighty")/len(text3)) * 100
# Out:
# 0.013403627915289072

# %% [markdown]
# ### Lets see how many times the word 'lol' appears in text5

# %%
from __future__ import division
(text5.count("lol")/len(text5)) * 100
# Out:
# 1.5640968673628082

# %% [markdown]
# #### Rather than repeating the same lines over and over again, lets write a function to make our lives easy.

# %%
def word_usage(text, word):
    return (text.count(word)/len(text)) * 100

# %%
num = word_usage(text3, "Almighty")

# %%
num
# Out:
# 0.013403627915289072

# %% [markdown]
# #### Likewise, lets have a function for determining the vocabulary richness of our text

# %%
def vocab_diversity(text):
    return len(set(text))/len(text)

# %%
vd_genesis = vocab_diversity(text3)

# %%
vd_genesis
# Out:
# 0.06230453042623537
